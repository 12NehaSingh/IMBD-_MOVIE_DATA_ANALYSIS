# %% [markdown]
# # importing Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing Dataset

# %%
data=pd.read_csv("IMDB-Movie-Data.csv")

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# # 1.Displaying top 10 rows and last 10 rows

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# # 2.  Getting information abouot our  dataset like  shape of dataset(i.e Total no. of rows and Total no. of columns) ,Data types of each column  and memory Requirement

# %%
data.shape
# Out:
# (1000, 12)

# %%
print("No. of rows in dataset",data.shape[0])
print("No of columns in dataset",data.shape[1])
# Out:
# No. of rows in dataset 1000
# No of columns in dataset 12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %% [markdown]
# # 3.Checking null values in dataset

# %%
print("Data set having missing values ?",data.isnull().values.any())
# Out:
# Data set having missing values ? True

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing=data.isnull().sum()*100/len(data)
per_missing
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %% [markdown]
# # 4.Drop all missing values

# %%
data.dropna(inplace=True)

# %% [markdown]
# # 5. Check for Duplicate Data

# %%
print("Are there any duplicate values ?",data.duplicated().any())
# Out:
# Are there any duplicate values ? False

# %% [markdown]
# # 6. Get overall statistics from Dataset

# %%
data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# # 7. Displaying the movie name having runtime greater than 180 minute

# %%
 data[data["Runtime (Minutes)"]>=180]["Title"]
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %% [markdown]
# # 8. In Which Year threre was average highest voting

# %%
data.groupby("Year")['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    290861.483871
# 2006    277232.219512
# 2009    267180.577778
# 2008    266580.145833
# 2007    266530.704545
# 2010    261082.929825
# 2011    259254.736842
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes by Year")
# Out:
# Text(0.5, 1.0, 'Votes by Year')

# %%
data.groupby("Year")['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Year
# 2009    115.742000
# 2012    110.103065
# 2010    105.081579
# 2008     97.525417
# 2011     93.703333
# 2007     93.074091
# 2013     88.084643
# 2006     87.255610
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# sns.barplot(x='Year',y='Revenue (Millions)',data=data)
# plt.title("Revenue by Year",color='g')

# %% [markdown]
# # 9. Average Rating for each Director

# %%
data.groupby("Director")['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %% [markdown]
# # 10.Top 10 lengthy movie Title and Runtime

# %%
top10_len=data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title')
top10_len
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %%
sns.barplot(x='Runtime (Minutes)',y=top10_len.index,data=top10_len)
plt.title("Top 10 movie Title and Runtime",color='m')
# Out:
# Text(0.5, 1.0, 'Top 10 movie Title and Runtime')

# %% [markdown]
# # 11. No. of movies per year

# %%
data["Year"].value_counts()
# Out:
# Year
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: count, dtype: int64

# %%
data.groupby("Year")["Title"].count()
# Out:
# Year
# 2006     41
# 2007     44
# 2008     48
# 2009     45
# 2010     57
# 2011     57
# 2012     62
# 2013     84
# 2014     93
# 2015    109
# 2016    198
# Name: Title, dtype: int64

# %%
sns.countplot(x='Year',data=data)
plt.title("No. of movies per year")
plt.show()

# %% [markdown]
# #  12. Most Popular Movie Title (Highest Revenue)

# %%
data[data['Revenue (Millions)']==data['Revenue (Millions)'].max()]["Title"]
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# #  13.Top 10 Highest Rated Movie Title and its Director

# %%
t=data.nlargest(10,"Rating")[['Title','Rating','Director']].set_index("Title")

# %%
sns.barplot(x="Rating",y=t.index,data=t,hue="Director",dodge=False)
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.title("Top 10 Highest Rated Movie Title and its Director")
# Out:
# Text(0.5, 1.0, 'Top 10 Highest Rated Movie Title and its Director')

# %% [markdown]
# # 14 Top 10 Highest  Revenue  Movie Titles

# %%
top_10=data.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']].set_index("Title")
top_10
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
sns.barplot(x='Revenue (Millions)',y=top_10.index,data=top_10)
plt.title("Top 10 Highest Revenue Movie Titles")
plt.show()

# %% [markdown]
# # 15.Average Rating of Movies per Year

# %%
data.groupby("Year")["Rating"].mean()
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2008    6.708333
# 2009    6.911111
# 2010    6.894737
# 2011    6.945614
# 2012    6.933871
# 2013    6.832143
# 2014    6.822581
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %%
sns.barplot(x="Year",y='Rating',data=data)
plt.title("Average Rating of Movies per Year")
plt.show()

# %% [markdown]
# #  16.Does Rating Affect the Revenue

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)
plt.show()
print("When the Rating is high Revenue is also high and vice versa so Rating  Affect the Revenue")
# Out:
# When the Rating is high Revenue is also high and vice versa so Rating  Affect the Revenue

# %% [markdown]
# # 17. Classify Movies based on Rating(Excellent,Good,Average,Need Improvement)

# %%
def rating1(rating) :
    if rating>7.0 :
        return "Excellent"
    elif rating > 6.0 :
        return "Good"
    elif rating > 5.0:
        return "Average"
    else :
        return "Need Improvement"
data['Rating category']=data['Rating'].apply(rating1)

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# # 18. Number of Action Movies

# %%
len(data[data['Genre'].str.contains("Action",case=False)])
# Out:
# 277

# %% [markdown]
# # 19.Finding Unique values from genre

# %%
data['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 993     Action,Adventure,Horror
# 994                      Comedy
# 996                      Horror
# 997         Drama,Music,Romance
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 838, dtype: object

# %%
list1=[]
for value in data['Genre'] :
    list1.append(value.split(","))

# %%
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Comedy'],
# ...

# %%
one_dim_list = []
for val1 in list1:
    for val2 in val1 :
        one_dim_list.append(val2)

# %%
one_dim_list
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Thriller',
# ...

# %%
set_genre=set(one_dim_list)

# %%
set_genre
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %%
len(set_genre)
# Out:
# 20

# %% [markdown]
# # 20. How  many films of each genre was made

# %%
form collections import coounter
couter(one_dim_list)

# %% [markdown]
# # 21.Number of Directors

# %%
data["Director"]
# Out:
# 0                James Gunn
# 1              Ridley Scott
# 2        M. Night Shyamalan
# 3      Christophe Lourdelet
# 4                David Ayer
#                ...
# 993      Paul W.S. Anderson
# 994         Nima Nourizadeh
# 996                Eli Roth
# 997              Jon M. Chu
# 999        Barry Sonnenfeld
# Name: Director, Length: 838, dtype: object

# %%
list2=[]
for i in data["Director"]:
    list2.append(i)

# %%
len(list2)
# Out:
# 838

# %%
set1=set(list2)

# %%
print("Total no. of directors are :",len(set1))
# Out:
# Total no. of directors are : 524

# %% [markdown]
# # 22. Total no. of movie made by each Director

# %%
top_dir=data.groupby("Director")["Title"].count().sort_values(ascending=False)
top_dir
# Out:
# Director
# Ridley Scott          8
# David Yates           6
# Michael Bay           6
# Paul W.S. Anderson    6
# J.J. Abrams           5
#                      ..
# James Mangold         1
# James Gray            1
# James DeMonaco        1
# James Cameron         1
# Zackary Adler         1
# Name: Title, Length: 524, dtype: int64

# %%
print("Name of the top 5 director who made mximum movie",top_dir.head())
# Out:
# Name of the top 5 director who made mximum movie Director
# Ridley Scott          8
# David Yates           6
# Michael Bay           6
# Paul W.S. Anderson    6
# J.J. Abrams           5
# Name: Title, dtype: int64

# %% [markdown]
# #  23 Total Number and Name of  Actors who  did the  movie

# %%
list3=[]
for val in data['Actors']:
    list3.append(val.split(","))
list3
# Out:
# [['Chris Pratt', ' Vin Diesel', ' Bradley Cooper', ' Zoe Saldana'],
#  ['Noomi Rapace',
#   ' Logan Marshall-Green',
#   ' Michael Fassbender',
#   ' Charlize Theron'],
#  ['James McAvoy', ' Anya Taylor-Joy', ' Haley Lu Richardson', ' Jessica Sula'],
#  ['Matthew McConaughey',
#   'Reese Witherspoon',
#   ' Seth MacFarlane',
#   ' Scarlett Johansson'],
#  ['Will Smith', ' Jared Leto', ' Margot Robbie', ' Viola Davis'],
#  ['Matt Damon', ' Tian Jing', ' Willem Dafoe', ' Andy Lau'],
#  ['Ryan Gosling', ' Emma Stone', ' Rosemarie DeWitt', ' J.K. Simmons'],
#  ['Charlie Hunnam', ' Robert Pattinson', ' Sienna Miller', ' Tom Holland'],
#  ['Jennifer Lawrence', ' Chris Pratt', ' Michael Sheen', 'Laurence Fishburne'],
#  ['Eddie Redmayne', ' Katherine Waterston', ' Alison Sudol', 'Dan Fogler'],
#  ['Taraji P. Henson', ' Octavia Spencer', ' Janelle Monáe', 'Kevin Costner'],
#  ['Felicity Jones', ' Diego Luna', ' Alan Tudyk', ' Donnie Yen'],
# ...

# %%
one_dim_list3=[]
for val1 in list3:
    for val2 in val1:
        one_dim_list3.append(val2)
(one_dim_list3)
# len(one_dim_list3)
# Out:
# ['Chris Pratt',
#  ' Vin Diesel',
#  ' Bradley Cooper',
#  ' Zoe Saldana',
#  'Noomi Rapace',
#  ' Logan Marshall-Green',
#  ' Michael Fassbender',
#  ' Charlize Theron',
#  'James McAvoy',
#  ' Anya Taylor-Joy',
#  ' Haley Lu Richardson',
#  ' Jessica Sula',
#  'Matthew McConaughey',
#  'Reese Witherspoon',
#  ' Seth MacFarlane',
#  ' Scarlett Johansson',
#  'Will Smith',
#  ' Jared Leto',
#  ' Margot Robbie',
#  ' Viola Davis',
#  'Matt Damon',
#  ' Tian Jing',
#  ' Willem Dafoe',
#  ' Andy Lau',
#  'Ryan Gosling',
#  ' Emma Stone',
#  ' Rosemarie DeWitt',
#  ' J.K. Simmons',
#  'Charlie Hunnam',
#  ' Robert Pattinson',
#  ' Sienna Miller',
#  ' Tom Holland',
#  'Jennifer Lawrence',
#  ' Chris Pratt',
#  ' Michael Sheen',
#  'Laurence Fishburne',
#  'Eddie Redmayne',
#  ' Katherine Waterston',
#  ' Alison Sudol',
#  'Dan Fogler',
#  'Taraji P. Henson',
#  ' Octavia Spencer',
#  ' Janelle Monáe',
#  'Kevin Costner',
#  'Felicity Jones',
#  ' Diego Luna',
#  ' Alan Tudyk',
# ...

# %%
set2=set(one_dim_list3)

# %%
print("Name eof the actors are:",set2)
# Out:
# Name eof the actors are: {' Ron Perlman', 'Evan Rachel Wood', ' Asa Butterfield', 'Anton Adasinsky', 'Riley Keough', ' Josh Brolin', ' Laurence Fishburne', 'Taron Egerton', ' Julianne Moore', 'Mark Ruffalo', ' Steven Mackintosh', ' Axel Devillers', 'Ian McKellen', ' Nick Frost', 'Billy Crystal', ' Robert Knepper', 'John Goodman', ' Anna Kendrick', ' Jason Sudeikis', 'Karl Urban', ' Orto Ignatiussen', ' Jeremy Irons', 'Sally Phillips', ' Christian Cooke', ' AJ Michalka', ' Mel Raido', 'Kristen Wiig', ' Lucy Fry', ' Oona Laurence', 'Jason Bateman', ' Ray Winstone', ' Bruce Greenwood', ' Octavia Spencer', ' Michael B. Jordan', ' Anton Yelchin', 'Paul Bettany', 'Gabriel Chavarria', ' Paula Patton', 'Alexander Black', ' David Spade', ' Vincent Kartheiser', ' Steve Carell', ' Gabriella Wilde', ' Vince Vaughn', 'Sharlto Copley', 'Edward Asner', ' Liam Neeson', 'Edith Scob', ' David Wenham', ' Max Irons', 'Winona Ryder', 'John Gallagher Jr.', 'Lee Pace', ' Jason Mitchell', ' Peter Dinklage',
# ...

# %%
print("Total Actors are :",len(set2))
# Out:
# Total Actors are : 1986

# %% [markdown]
# # 24. Number of Adventure,Action,Drama,Horror,Family,Comedy,Fantasy And Romance movies

# %%
x1=len(data[data["Genre"].str.contains("Adventure",case=False)])
print("Total no. of Adventure movie:",x1)
# Out:
# Total no. of Adventure movie: 244

# %%
x2=len(data[data["Genre"].str.contains("Horror",case=False)])
print("Total no. of Horror movie:",x2)
# Out:
# Total no. of Horror movie: 87

# %%
x3=len(data[data["Genre"].str.contains("Family",case=False)])
print("Total no. of Family movie:",x3)
# Out:
# Total no. of Family movie: 48

# %%
x4=len(data[data["Genre"].str.contains("Comedy",case=False)])
print("Total no. of Comedy movie:",x4)
# Out:
# Total no. of Comedy movie: 250

# %%
x5=len(data[data["Genre"].str.contains("Romance",case=False)])
print("Total no. of Romance movie:",x5)
# Out:
# Total no. of Romance movie: 120

# %%
x6=len(data[data["Genre"].str.contains("Drama",case=False)])
print("Total no. of Drama movie:",x6)
# Out:
# Total no. of Drama movie: 419

# %%
x7=len(data[data["Genre"].str.contains("Fantasy",case=False)])
print("Total no. of Fantasy movie:",x7)
# Out:
# Total no. of Fantasy movie: 92

# %%
x8=len(data[data["Genre"].str.contains("Action",case=False)])
print("Total no. of Action movie:",x8)
# Out:
# Total no. of Action movie: 277

# %%
x=['Action','Adventure','Fantasy','Drama','Comedy','Family','Horror','Romance']
y=[x8,x1,x7,x6,x4,x3,x2,x5]
plt.barh(x,y,color=['y','g','b','m','r'],alpha=0.6)
plt.title("Counts of movie by some Genre")
plt.show()
